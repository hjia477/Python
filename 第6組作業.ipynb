# %% [markdown]
# <a href="https://colab.research.google.com/github/hjia477/Python/blob/main/%E7%AC%AC6%E7%B5%84%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業繳交資訊
# #### 請同學將作業下載成「第 n 組作業.ipynb」後上傳至[python作業繳交區表單](https://forms.gle/H2XP3vj8qhjN3rhX9)
# #### 每組只需上傳1份
# #### 作業可以討論，但請勿抄襲（借別人抄跟抄別人的都連坐罰）

# %% [markdown]
# # 分組資訊
# ## 組別：6
# ## 主題：
#   變數:Industry
#   選項:Healthcare
# ## 組員名單（學號/姓名）：
# 1.412351615 黃郁嘉
#
# 2.412351603 吳佩諭
#
# 3.412301581 常嘉豫

# %% [markdown]
# # 資料集說明
# 資料集來源：[ESG & Financial Performance Dataset](https://www.kaggle.com/datasets/shriyashjagtap/esg-and-financial-performance-dataset)
#
# 欄位名稱及資料型態
# 1. 公司代碼(CompanyID)：Object
# 2. 產業(Industry)：Object
# 3. 所在地區(Region)：Object
# 4. 資料年份(Year)：int
# 5. 年收入_百萬美元(Revenue)：float
# 6. 邊際利潤(ProfitMargin)：float
# 7. 市值_百萬美元(MarketCap)：float
# 8. 年收成長率(GrowthRate)：float
# 9. ESG總得分(ESG_Overall)：float
# 10. 永續環境(ESG_Environmental)：float
# 11. 社會責任(ESG_Social)：float
# 12. 公司治理(ESG_Governance)：float
# 13. 二氧化碳排放量(CarbonEmissions)：float
# 14. 用水量(WaterUsage)：float
# 15. 能源消費(EnergyConsumption)：float

# %% [markdown]
# # 第一題、匯入資料集(17% = 4% + 4% + 9%)
# #### (1)利用input指令讓使用者自行輸入已共享google試算表的連結代碼（變數名稱為ID）以取得後續資料
# #### (2)將抓取google試算表的下載網址定義成一個字串變數(Filename)
# #### (3)利用pandas中的read_excel分別讀入「Financial_Data」、「ESG_Score」、「OTHERS」三張頁籤的資料（工作表名稱即為資料集的變數名稱）

# %%
from google.colab import drive
drive.mount('/content/drive')

#連接Google的指令
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

sheets = pd.read_excel(Filename, sheet_name=None)

df_financial = sheets['Financial_Data']
df_esg = sheets['ESG_Score']
df_others = sheets['OTHERS']

# %%
ID=input("......google試算表的代碼連結: ")
Filename="https://drive.google.com/uc?id=" + ID + "&export=download"

Country=pd.read_excel(Filename,sheet_name="Financial_Data")
Country
# Out:
# ......google試算表的代碼連結: 1k6Z3sTYw-HKyvpBaHHi6mr_AFVqK5_Nz
#      CompanyID        Industry         Region  Year  Revenue  ProfitMargin  \
# 0            1          Retail  Latin America  2025    734.5           5.0
# 1            2          Retail           Asia  2025   4371.5          -2.4
# 2            3  Transportation  Latin America  2025    479.8          11.6
# 3            4      Technology         Africa  2025   7675.6          22.9
# 4            5         Finance    Middle East  2025   3162.1          22.4
# ..         ...             ...            ...   ...      ...           ...
# 995        996      Healthcare         Europe  2025   5503.9          20.3
# 996        997       Utilities         Africa  2025    642.9          10.2
# 997        998      Healthcare        Oceania  2025   2042.3          29.8
# 998        999         Finance           Asia  2025   5700.3          21.6
# 999       1000  Consumer Goods  Latin America  2025   3173.5          17.5
#
# ...

# %%
ID=input("......google試算表的代碼連結: ")
Filename="https://drive.google.com/uc?id=" + ID + "&export=download"
Country=pd.read_excel(Filename,sheet_name="ESG_Score")
Country
# Out:
# ......google試算表的代碼連結: 1k6Z3sTYw-HKyvpBaHHi6mr_AFVqK5_Nz
#      CompanyID  ESG_Overall  ESG_Environmental  ESG_Social  ESG_Governance
# 0            1         59.2               70.7        29.1            78.0
# 1            2         66.3               65.8        62.8            70.3
# 2            3         34.3               24.4        43.7            34.9
# 3            4         64.1              100.0        65.4            27.0
# 4            5         48.0               82.1        18.7            43.3
# ..         ...          ...                ...         ...             ...
# 995        996         60.4               91.3        32.9            56.9
# 996        997         66.7               49.5        91.4            59.2
# 997        998         65.6              100.0        31.7            65.2
# 998        999         53.1              100.0        16.2            43.1
# 999       1000         51.8               74.5        39.7            41.4
#
# ...

# %%
ID=input("......google試算表的代碼連結: ")
Filename="https://drive.google.com/uc?id=" + ID + "&export=download"
Country=pd.read_excel(Filename,sheet_name="OTHERS")
Country
# Out:
# ......google試算表的代碼連結: 1k6Z3sTYw-HKyvpBaHHi6mr_AFVqK5_Nz
#      CompanyID  CarbonEmissions  WaterUsage  EnergyConsumption
# 0            1          51805.8     25902.9           103611.7
# 1            2         323282.0    161641.0           646564.1
# 2            3         296242.0     49373.7           987473.3
# 3            4         191891.1    115134.7           383782.3
# 4            5          39561.3     19780.6            98903.2
# ..         ...              ...         ...                ...
# 995        996         308688.0    308688.0           617376.0
# 996        997         439038.9    274399.3          4390388.8
# 997        998         102112.6    102112.6           204225.2
# 998        999          57003.4     28501.7           142508.6
# 999       1000         430741.6    538427.0          2153707.9
#
# [1000 rows x 4 columns]

# %% [markdown]
# # 第二題、合併資料集（用pd.merge 或 pd.concat）(5%)
# #### 請將上面三個資料集（Financial_Data、ESG_Score、OTHERS）合併成一個資料集(Company_ESG)

# %%
merged_df = pd.merge( df_financial , df_esg , on=["CompanyID"	, "ESG_Overall" , "ESG_Environmental" , "ESG_Social" , "ESG_Governance"],how="outer")

Company_ESG = pd.merge( merged_df , df_others , on=["CompanyID"	, "CarbonEmissions" , "WaterUsage" , "EnergyConsumption"],how="outer")

# %%
print(Company_ESG.head())
# Out:
#    CompanyID        Industry         Region  Year  Revenue  ProfitMargin  \
# 0          1          Retail  Latin America  2025    734.5           5.0
# 1          2          Retail           Asia  2025   4371.5          -2.4
# 2          3  Transportation  Latin America  2025    479.8          11.6
# 3          4      Technology         Africa  2025   7675.6          22.9
# 4          5         Finance    Middle East  2025   3162.1          22.4
#
#    MarketCap  GrowthRate  ESG_Overall  ESG_Environmental  ESG_Social  \
# 0      628.8         6.9         59.2               70.7        29.1
# 1    20376.3        14.4         66.3               65.8        62.8
# 2     1020.7         9.5         34.3               24.4        43.7
# 3    42400.4        17.1         64.1              100.0        65.4
# 4     6674.6        -3.7         48.0               82.1        18.7
#
#    ESG_Governance  CarbonEmissions  WaterUsage  EnergyConsumption
# ...

# %% [markdown]
# # 第三題、確認資料型態(10%)
# #### 請用info()確認「資料集Company_ESG」的資料型態是否符合上述資料集說明中的定義，如果不符合，請轉成適合的型別，再存回「資料集Company_ESG」中。

# %%
Company_ESG.info()

#顯示Company_ESG的資料
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CompanyID          1000 non-null   int64
#  1   Industry           1000 non-null   object
#  2   Region             1000 non-null   object
#  3   Year               1000 non-null   int64
#  4   Revenue            1000 non-null   float64
#  5   ProfitMargin       1000 non-null   float64
#  6   MarketCap          1000 non-null   float64
#  7   GrowthRate         1000 non-null   float64
#  8   ESG_Overall        1000 non-null   float64
#  9   ESG_Environmental  1000 non-null   float64
#  10  ESG_Social         1000 non-null   float64
#  11  ESG_Governance     1000 non-null   float64
#  12  CarbonEmissions    1000 non-null   float64
#  13  WaterUsage         1000 non-null   float64
#  14  EnergyConsumption  1000 non-null   float64
# dtypes: float64(11), int64(2), object(2)
# ...

# %%
Company_ESG["CompanyID"]=Company_ESG["CompanyID"].to_string()

#改資料型態

# %%
Company_ESG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CompanyID          1000 non-null   object
#  1   Industry           1000 non-null   object
#  2   Region             1000 non-null   object
#  3   Year               1000 non-null   int64
#  4   Revenue            1000 non-null   float64
#  5   ProfitMargin       1000 non-null   float64
#  6   MarketCap          1000 non-null   float64
#  7   GrowthRate         1000 non-null   float64
#  8   ESG_Overall        1000 non-null   float64
#  9   ESG_Environmental  1000 non-null   float64
#  10  ESG_Social         1000 non-null   float64
#  11  ESG_Governance     1000 non-null   float64
#  12  CarbonEmissions    1000 non-null   float64
#  13  WaterUsage         1000 non-null   float64
#  14  EnergyConsumption  1000 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# ...

# %% [markdown]
# # 第四題、刪除特定資料(5%)
# #### 因此資料皆為2025年的資料，所以「資料集Company_ESG」中的year皆相同，無區別性，故請用drop()將此year刪除，並存回「資料集Company_ESG」的year中

# %%
Company_ESG = Company_ESG.drop('Year', axis=1)
#刪除year的資料

print(Company_ESG)
# Out:
#                                              CompanyID        Industry  \
# 0    0         1\n1         2\n2         3\n3      ...          Retail
# 1    0         1\n1         2\n2         3\n3      ...          Retail
# 2    0         1\n1         2\n2         3\n3      ...  Transportation
# 3    0         1\n1         2\n2         3\n3      ...      Technology
# 4    0         1\n1         2\n2         3\n3      ...         Finance
# ..                                                 ...             ...
# 995  0         1\n1         2\n2         3\n3      ...      Healthcare
# 996  0         1\n1         2\n2         3\n3      ...       Utilities
# 997  0         1\n1         2\n2         3\n3      ...      Healthcare
# 998  0         1\n1         2\n2         3\n3      ...         Finance
# 999  0         1\n1         2\n2         3\n3      ...  Consumer Goods
#
#             Region  Revenue  ProfitMargin  MarketCap  GrowthRate  ESG_Overall  \
# ...

# %%
Company_ESG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CompanyID          1000 non-null   object
#  1   Industry           1000 non-null   object
#  2   Region             1000 non-null   object
#  3   Revenue            1000 non-null   float64
#  4   ProfitMargin       1000 non-null   float64
#  5   MarketCap          1000 non-null   float64
#  6   GrowthRate         1000 non-null   float64
#  7   ESG_Overall        1000 non-null   float64
#  8   ESG_Environmental  1000 non-null   float64
#  9   ESG_Social         1000 non-null   float64
#  10  ESG_Governance     1000 non-null   float64
#  11  CarbonEmissions    1000 non-null   float64
#  12  WaterUsage         1000 non-null   float64
#  13  EnergyConsumption  1000 non-null   float64
# dtypes: float64(11), object(3)
# memory usage: 109.5+ KB

# %% [markdown]
# # 第五題、欄位名稱變更及重新定義資料集索引(10%)
# #### (1)請用rename將「CompanyID」更名為「ID」，以及「CarbonEmissions」更名為「CO2排放量」，並存回「資料集Company_ESG」中
# #### (2)請用set_index將ID定義為「資料集Company_ESG」的索引

# %%
Company_ESG.rename(columns={"CompanyID":"ID","CarbonEmissions":"CO2排放量"})

#改名字改名字
# Out:
#                                                     ID        Industry  \
# 0    0         1\n1         2\n2         3\n3      ...          Retail
# 1    0         1\n1         2\n2         3\n3      ...          Retail
# 2    0         1\n1         2\n2         3\n3      ...  Transportation
# 3    0         1\n1         2\n2         3\n3      ...      Technology
# 4    0         1\n1         2\n2         3\n3      ...         Finance
# ..                                                 ...             ...
# 995  0         1\n1         2\n2         3\n3      ...      Healthcare
# 996  0         1\n1         2\n2         3\n3      ...       Utilities
# 997  0         1\n1         2\n2         3\n3      ...      Healthcare
# 998  0         1\n1         2\n2         3\n3      ...         Finance
# 999  0         1\n1         2\n2         3\n3      ...  Consumer Goods
#
#             Region  Revenue  ProfitMargin  MarketCap  GrowthRate  ESG_Overall  \
# ...

# %%
Company_ESG = Company_ESG.rename(columns={"CompanyID":"ID","CarbonEmissions":"CO2排放量"})
#加等於存回去

# %%
Company_ESG.set_index('ID')
# Out:
#                                                           Industry  \
# ID
# 0         1\n1         2\n2         3\n3       ...          Retail
# 0         1\n1         2\n2         3\n3       ...          Retail
# 0         1\n1         2\n2         3\n3       ...  Transportation
# 0         1\n1         2\n2         3\n3       ...      Technology
# 0         1\n1         2\n2         3\n3       ...         Finance
# ...                                                            ...
# 0         1\n1         2\n2         3\n3       ...      Healthcare
# 0         1\n1         2\n2         3\n3       ...       Utilities
# 0         1\n1         2\n2         3\n3       ...      Healthcare
# 0         1\n1         2\n2         3\n3       ...         Finance
# 0         1\n1         2\n2         3\n3       ...  Consumer Goods
#
#                                                            Region  Revenue  \
# ID
# 0         1\n1         2\n2         3\n3       ...  Latin America    734.5
# ...

# %% [markdown]
# # 第六題、資料排序(5%)
# #### 請將「資料集Company_ESG」的資料依ESG_Overall大小由大至小排序，並將排序結果回存至「資料集Company_ESG」中

# %%
Company_ESG.sort_values(by='ESG_Overall', ascending=False)
# Out:
#                                                     ID        Industry  \
# 477  0         1\n1         2\n2         3\n3      ...         Finance
# 869  0         1\n1         2\n2         3\n3      ...         Finance
# 471  0         1\n1         2\n2         3\n3      ...      Healthcare
# 156  0         1\n1         2\n2         3\n3      ...  Consumer Goods
# 377  0         1\n1         2\n2         3\n3      ...      Technology
# ..                                                 ...             ...
# 83   0         1\n1         2\n2         3\n3      ...  Consumer Goods
# 140  0         1\n1         2\n2         3\n3      ...          Energy
# 184  0         1\n1         2\n2         3\n3      ...  Transportation
# 301  0         1\n1         2\n2         3\n3      ...          Energy
# 310  0         1\n1         2\n2         3\n3      ...  Consumer Goods
#
#             Region  Revenue  ProfitMargin  MarketCap  GrowthRate  ESG_Overall  \
# ...

# %%
Company_ESG = Company_ESG.sort_values(by='ESG_Overall', ascending=False)

# %% [markdown]
# # 第七題、重新定義變數涵意及新增變數(18% = 3% + 10% + 5%)
# #### (1)建立一個空的list變數(New_Group)
# #### (2)利用for迴圈及ifelse判斷式將「資料集Company_ESG」中的ESG_Overall重新定義成3組別：
# - 小於60分(不含60)
# - 60-80分(不含80)
# - 80分以上
#
# #### (3)在「資料集Company_ESG」中新增一個欄位為「ESG成績分組」。

# %%
New_Group=list()
for i in Company_ESG["ESG_Overall"]:
    if i < 60:
        New_Group.append("小於60分(不含60)")
    elif i < 80:
        New_Group.append("60-80分(不含80)")
    else:
        New_Group.append("80分以上")
New_Group
# Out:
# ['80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '80分以上',
#  '60-80分(不含80)',
#  '60-80分(不含80)',
# ...

# %%
Company_ESG["ESG成績分組"] = New_Group
Company_ESG
# Out:
#                                                     ID        Industry  \
# 477  0         1\n1         2\n2         3\n3      ...         Finance
# 869  0         1\n1         2\n2         3\n3      ...         Finance
# 471  0         1\n1         2\n2         3\n3      ...      Healthcare
# 156  0         1\n1         2\n2         3\n3      ...  Consumer Goods
# 377  0         1\n1         2\n2         3\n3      ...      Technology
# ..                                                 ...             ...
# 83   0         1\n1         2\n2         3\n3      ...  Consumer Goods
# 140  0         1\n1         2\n2         3\n3      ...          Energy
# 184  0         1\n1         2\n2         3\n3      ...  Transportation
# 301  0         1\n1         2\n2         3\n3      ...          Energy
# 310  0         1\n1         2\n2         3\n3      ...  Consumer Goods
#
#             Region  Revenue  ProfitMargin  MarketCap  GrowthRate  ESG_Overall  \
# ...

# %% [markdown]
# # 第八題、資料篩選(loc)(10%)
# #### 依分組名單中的主題選取符合主題條件的列資料，以及須保留以下欄位，並另存成「資料集ESG_NumericData」：
# 1. ESG_Overall
# 2. ESG_Environmental
# 3. ESG_Social
# 4. ESG_Governance
# 5. CO2排放量
# 6. WaterUsage
# 7. EnergyConsumption

# %%
ESG_NumericData = Company_ESG.loc[Company_ESG['Industry'] == 'Healthcare', ["ESG_Overall","ESG_Environmental","ESG_Social","ESG_Governance","CO2排放量","WaterUsage","EnergyConsumption"]]

ESG_NumericData
# Out:
#      ESG_Overall  ESG_Environmental  ESG_Social  ESG_Governance     CO2排放量  \
# 471         95.6               96.5        99.2            91.3   259802.9
# 606         88.1               95.5        88.3            80.4  3265464.3
# 322         85.5               70.4       100.0            86.1   263194.0
# 293         85.4               78.3        87.0            90.8    56988.0
# 167         83.8              100.0        52.1            99.4   133681.8
# ..           ...                ...         ...             ...        ...
# 582         28.4               33.5        31.1            20.5   912577.5
# 888         27.9               34.5        18.4            30.6   376929.1
# 638         27.0               21.9        31.3            27.9   291914.5
# 109         26.6               57.1         7.8            15.0   349991.9
# 373         23.8               48.5        19.6             3.1   892862.8
#
#      WaterUsage  EnergyConsumption
# ...

# %% [markdown]
# # 第九題、計算統計量(10% = 4% + 3% + 3%)
# #### 請以「資料集ESG_NumericData」計算：
# 1. 所有欄位個別的平均數、標準差
# 2. EnergyConsumption的中位數
# 3. 所有變數的變異係數矩陣

# %%
ESG_NumericData.mean()
#這是算平均數的
# Out:
# ESG_Overall              60.462810
# ESG_Environmental        70.904959
# ESG_Social               54.219008
# ESG_Governance           56.261983
# CO2排放量               479984.585124
# WaterUsage           479984.585124
# EnergyConsumption    959969.174380
# dtype: float64

# %%
ESG_NumericData.std()
#這是算標準差的
# Out:
# ESG_Overall          1.533553e+01
# ESG_Environmental    1.910743e+01
# ESG_Social           2.410286e+01
# ESG_Governance       2.518376e+01
# CO2排放量               5.823583e+05
# WaterUsage           5.823583e+05
# EnergyConsumption    1.164717e+06
# dtype: float64

# %%
ESG_NumericData["EnergyConsumption"].median()
#這是算EnergyConsumption的中位數的
# Out:
# 596704.2

# %%
#計算每列的變異係數
coefficient_of_variation = ESG_NumericData.std() / ESG_NumericData.mean()

coefficient_of_variation
# Out:
# ESG_Overall          0.253636
# ESG_Environmental    0.269479
# ESG_Social           0.444546
# ESG_Governance       0.447616
# CO2排放量               1.213285
# WaterUsage           1.213285
# EnergyConsumption    1.213285
# dtype: float64

# %% [markdown]
# # 第十題、資料分組(groupby或pivot_table)(10% = 4% + 2% + 2% + 2%)
# #### 請以「資料集Company_ESG」的「ESG成績分組」欄位進行分組，分別計算各組之資料筆數及最大、最小值

# %%
Company_ESG.groupby('ESG成績分組').agg(['count', 'max', 'min'])
# Out:
#                 ID                                                     \
#              count                                                max
# ESG成績分組
# 60-80分(不含80)   379  0         1\n1         2\n2         3\n3      ...
# 80分以上           79  0         1\n1         2\n2         3\n3      ...
# 小於60分(不含60)    542  0         1\n1         2\n2         3\n3      ...
#
#                                                                 Industry  \
#                                                             min    count
# ESG成績分組
# 60-80分(不含80)  0         1\n1         2\n2         3\n3      ...      379
# 80分以上         0         1\n1         2\n2         3\n3      ...       79
# 小於60分(不含60)   0         1\n1         2\n2         3\n3      ...      542
#
#                                         Region                  Revenue  ...  \
#                     max             min  count      max     min   count  ...
# ...

# %% [markdown]
# # 第十一題、請以「資料集Company_ESG」繪製以下統計圖表：(20%)
# 1. ESG_Environmental的直方圖
# 2. 以「Industry」為分組依據，ESG_Overall的盒形圖
# 3. 以第十題中的「ESG成績分組」資料筆數的圓餅圖
# 4. 「Revenue」及「EnergyConsumption」兩變數的散佈圖

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
tab = Company_ESG["ESG_Environmental"].hist(color=("#D1BBFF"))
tab
# Out:
# <Axes: >

# %%
tab2 = Company_ESG.boxplot(column='ESG_Overall', by='Industry')
tab2.tick_params(axis='x', rotation=45)

tab2
# Out:
# <Axes: title={'center': 'ESG_Overall'}, xlabel='Industry'>

# %%
Company_ESG.plot(kind="scatter",x="Revenue",y="EnergyConsumption",c="#FFAA33")
# Out:
# <Axes: xlabel='Revenue', ylabel='EnergyConsumption'>
